# %%
import numpy as np 
from matplotlib import pyplot as plt 
np.set_printoptions(suppress=True, precision=3)

# %%
with open('../airfoils/tkv2008.dat','r') as f:
    airfoil = f.read().strip()
airfoil = airfoil.split('\n')[2:]
airfoil = [row.split('\t') for row in airfoil]
airfoil = np.round(np.array(airfoil,dtype=float),4)

bordo_de_ataque = np.argmin(airfoil[:,0])
bordo_de_fuga   = 0

# %%
airfoil = airfoil * 200

# %%
airfoil[np.nanargmin(np.abs(airfoil[:130,0]-50))]
# Out:
# array([50.24, 30.52])

# %%
airfoil[130+np.nanargmin(np.abs(airfoil[130:,0]-50))]
# Out:
# array([50.6 ,  4.78])

# %%
max(airfoil[:,1])
# Out:
# 32.14

# %%
30.52-4.78
# Out:
# 25.74

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
ax.plot(airfoil[:,0],airfoil[:,1],'.')
ax.set_aspect('equal')
ax.plot([airfoil[bordo_de_ataque,0],airfoil[bordo_de_fuga,0]],[airfoil[bordo_de_ataque,1],airfoil[bordo_de_fuga,1]],'r-')
ax.plot([50.6,50.24],[4.78,30.52],'g-')

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
airfoil = airfoil*200
ax.plot(airfoil[:,0],airfoil[:,1],'.')
ax.set_aspect('equal')
ax.plot([airfoil[bordo_de_ataque,0],airfoil[bordo_de_fuga,0]],[airfoil[bordo_de_ataque,1],airfoil[bordo_de_fuga,1]],'r-')

# %%
airf = np.round(airfoil,4)
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
ax.plot(airf[:,0],airf[:,1],'.')
ax.set_aspect('equal')
ax.plot([airf[bordo_de_ataque,0],airf[bordo_de_fuga,0]],[airf[bordo_de_ataque,1],airf[bordo_de_fuga,1]],'r-')

# %%
airfoil[100]
# Out:
# array([0.05748, 0.07724])

# %%
airfoil[airfoil[:,0] == airfoil[100,0]]
# Out:
# array([[0.05748, 0.07724]])

# %%
airfoil[bordo_de_fuga]
# Out:
# array([1.e+00, 3.e-05])

# %%
### Constants

T0  = 288.15            # K
T   = (37 + 273.15)     # K
P0  = 1013.15           # hPa
P   = 936               # hPa

# %%
AltitudeDensidade = T0/0.0065 * (1 - ((P/P0)/(T/T0))**0.234959)
AltitudeDensidade

# %%
P   = 950.4            # hPa
T   = 20 + 273.15
AltitudeDensidade = T0/0.0065 * (1 - ((P/P0)/(T/T0))**0.234959)
AltitudeDensidade
# Out:
# 837.1405879325879
