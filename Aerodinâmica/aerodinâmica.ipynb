# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
alpha, reynolds, cl, cd, cm = np.load('..\\Aerodynamics\\tkv2008_analysis_3.npy',allow_pickle=True)

# %%
### Constants
AIR_DENSITY     = 1.225         * 1e0   # kg/m**3
AIR_VISCOSITY   = 1.7894e-5     * 1e0   # kg/m/s  or Pa*s (Dynamic)
# AIR_DENSITY = 1.1368


### Config
MEAN_CHORD      = 250           * 1e-3  # mm
WINGSPAN        = 1400          * 1e-3  # mm
ASPECT_RATIO    = WINGSPAN/MEAN_CHORD

# %%
idrag = 0.035
efficiency = 1/(1+idrag)

# %%
cl = cl[:,15]
cd = cd[:,15]
cm = cm[:,15]

# %%
index_cl0 = np.nanargmin(np.abs(cl))
index_clmax = np.nanargmin(np.abs(alpha-alpha[np.nanargmax(cl)]*0.9))

# %%
plt.plot(alpha,cl)

# %%
clalpha = np.mean((cl[index_cl0+1:index_clmax]-cl[index_cl0:index_clmax-1])/(alpha[index_cl0+1:index_clmax]-alpha[index_cl0:index_clmax-1]))

# %%
plt.plot(alpha[:index_clmax],clalpha*(alpha[:index_clmax]-alpha[index_cl0]))
plt.plot(alpha,cl)

# %%
np.array([6, 16, 26, 36, 46, 56]).reshape((-1, 1))
# Out:
# array([[ 6],
#        [16],
#        [26],
#        [36],
#        [46],
#        [56]])

# %%
v = 12
cl = 1.0
rho = AIR_DENSITY 
s = MEAN_CHORD*WINGSPAN

# %%
L = rho * v**2/2 * cl * s
L/10
# Out:
# 3.0870000000000006

# %%
L = rho * v**2/2 * cl/1.5 * 0.1*0.3
L
# Out:
# 1.7640000000000002

# %% [markdown]
# Geometria da asa
# Volume de cauda
# CL e CD da aeronave completa
# Tração
