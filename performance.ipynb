# %% [markdown]
# Helix
#
# 11x6
# 10x4.5          *5
# 12x6
# 11x4.7

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
with open('airfoils/tkv2008.dat','r') as f:
    airfoil = f.read().strip()
airfoil = airfoil.split('\n')[2:]
airfoil = [row.split('\t') for row in airfoil]
airfoil = np.array(airfoil,dtype=np.float64)

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(1,1,1)
ax.plot(airfoil[:,0],airfoil[:,1])
ax.set_aspect('equal')

# %%
AltitudeDensidade = T0/0.0065 * (1 - ((P/P0)/(T/T0))**0.234959)
AltitudeDensidade

# %%
P   = 950.4            # hPa
T   = 20 + 273.15
AltitudeDensidade = T0/0.0065 * (1 - ((P/P0)/(T/T0))**0.234959)
AltitudeDensidade
# Out:
# 837.1405879325879
